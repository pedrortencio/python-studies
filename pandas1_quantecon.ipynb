# %%
import pandas as pd

# Don't worry about this line for now!
# %matplotlib inline

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
values = [5.6, 5.3, 4.3, 4.2, 5.8, 5.3, 4.6, 7.8, 9.1, 8., 5.7]
years = list(range(1995, 2017, 2))

unemp = pd.Series(data=values, index=years, name="Unemployment")

# %%
unemp
# Out:
# 1995    5.6
# 1997    5.3
# 1999    4.3
# 2001    4.2
# 2003    5.8
# 2005    5.3
# 2007    4.6
# 2009    7.8
# 2011    9.1
# 2013    8.0
# 2015    5.7
# Name: Unemployment, dtype: float64

# %%
unemp.index
# Out:
# Index([1995, 1997, 1999, 2001, 2003, 2005, 2007, 2009, 2011, 2013, 2015], dtype='int64')

# %%
unemp.values
# Out:
# array([5.6, 5.3, 4.3, 4.2, 5.8, 5.3, 4.6, 7.8, 9.1, 8. , 5.7])

# %%
unemp.plot()
# Out:
# <Axes: >

# %%
unemp.loc[[1995, 2005, 2015]]
# Out:
# 1995    5.6
# 2005    5.3
# 2015    5.7
# Name: Unemployment, dtype: float64

# %%
# Exercise 1

#Display only the first 2 elements of the Series using the .head method.

print("- The first two elements of the Series are", unemp.head(2))

#Using the plot method, make a bar plot.

unemp.plot.bar()

#Use .loc to select the lowest/highest unemployment rate shown in the Series.

print("- The highest unemployment rate shown in the Series is:", unemp.loc[unemp.idxmax()])
print("- The lowest unemployment rate shown in the Series is:", unemp.loc[unemp.idxmin()])
# Out:
# - The first two elements of the Series are 1995    5.6
# 1997    5.3
# Name: Unemployment, dtype: float64
# - The highest unemployment rate shown in the Series is: 9.1
# - The lowest unemployment rate shown in the Series is: 4.2

# %%
data = {
    "NorthEast": [5.9,  5.6,  4.4,  3.8,  5.8,  4.9,  4.3,  7.1,  8.3,  7.9,  5.7],
    "MidWest": [4.5,  4.3,  3.6,  4. ,  5.7,  5.7,  4.9,  8.1,  8.7,  7.4,  5.1],
    "South": [5.3,  5.2,  4.2,  4. ,  5.7,  5.2,  4.3,  7.6,  9.1,  7.4,  5.5],
    "West": [6.6, 6., 5.2, 4.6, 6.5, 5.5, 4.5, 8.6, 10.7, 8.5, 6.1],
    "National": [5.6, 5.3, 4.3, 4.2, 5.8, 5.3, 4.6, 7.8, 9.1, 8., 5.7]
}

unemp_region = pd.DataFrame(data, index=years)
unemp_region
# Out:
#       NorthEast  MidWest  South  West  National
# 1995        5.9      4.5    5.3   6.6       5.6
# 1997        5.6      4.3    5.2   6.0       5.3
# 1999        4.4      3.6    4.2   5.2       4.3
# 2001        3.8      4.0    4.0   4.6       4.2
# 2003        5.8      5.7    5.7   6.5       5.8
# 2005        4.9      5.7    5.2   5.5       5.3
# 2007        4.3      4.9    4.3   4.5       4.6
# 2009        7.1      8.1    7.6   8.6       7.8
# 2011        8.3      8.7    9.1  10.7       9.1
# 2013        7.9      7.4    7.4   8.5       8.0
# 2015        5.7      5.1    5.5   6.1       5.7

# %%
unemp_region.plot()
# Out:
# <Axes: >

# %%
unemp_region.loc[[1995, 2005], "South"]
# Out:
# 1995    5.3
# 2005    5.2
# Name: South, dtype: float64

# %%
unemp_region.loc[1995, ["NorthEast", "National"]]
# Out:
# NorthEast    5.9
# National     5.6
# Name: 1995, dtype: float64

# %%
unemp_region.loc[:, "NorthEast"]
# Out:
# 1995    5.9
# 1997    5.6
# 1999    4.4
# 2001    3.8
# 2003    5.8
# 2005    4.9
# 2007    4.3
# 2009    7.1
# 2011    8.3
# 2013    7.9
# 2015    5.7
# Name: NorthEast, dtype: float64

# %%
unemp_region["MidWest"]
# Out:
# 1995    4.5
# 1997    4.3
# 1999    3.6
# 2001    4.0
# 2003    5.7
# 2005    5.7
# 2007    4.9
# 2009    8.1
# 2011    8.7
# 2013    7.4
# 2015    5.1
# Name: MidWest, dtype: float64

# %%
unemp_region["West"] / 100
# Out:
# 1995    0.066
# 1997    0.060
# 1999    0.052
# 2001    0.046
# 2003    0.065
# 2005    0.055
# 2007    0.045
# 2009    0.086
# 2011    0.107
# 2013    0.085
# 2015    0.061
# Name: West, dtype: float64

# %%
# Find maximum
unemp_region["West"].max()
# Out:
# 10.7

# %%
# Find the difference between two columns
# Notice that pandas applies `-` to _all rows_ at once
# We'll see more of this throughout these materials
unemp_region["West"] - unemp_region["MidWest"]
# Out:
# 1995    2.1
# 1997    1.7
# 1999    1.6
# 2001    0.6
# 2003    0.8
# 2005   -0.2
# 2007   -0.4
# 2009    0.5
# 2011    2.0
# 2013    1.1
# 2015    1.0
# dtype: float64

# %%
# Find correlation between two columns
unemp_region.West.corr(unemp_region["MidWest"])
# Out:
# 0.9006381255384481

# %%
# find correlation between all column pairs
unemp_region.corr()
# Out:
#            NorthEast   MidWest     South      West  National
# NorthEast   1.000000  0.875654  0.964415  0.967875  0.976016
# MidWest     0.875654  1.000000  0.951379  0.900638  0.952389
# South       0.964415  0.951379  1.000000  0.987259  0.995030
# West        0.967875  0.900638  0.987259  1.000000  0.981308
# National    0.976016  0.952389  0.995030  0.981308  1.000000

# %%
# Exercise 2

# Use introspection (or google-fu) to find a way to obtain a list with all of the column names in unemp_region.

print("The columns are:", unemp_region.columns)

# Using the plot method, make a bar plot. What does it look like now?

print(unemp_region.plot.bar())

# Use .loc to select the the unemployment data for the NorthEast and West for the years 1995, 2005, 2011, and 2015.

print(unemp_region.loc[[1995, 2005, 2011, 2015], ["NorthEast", "West"]])
# Out:
# The columns are: Index(['NorthEast', 'MidWest', 'South', 'West', 'National'], dtype='object')
# Axes(0.125,0.11;0.775x0.77)
#       NorthEast  West
# 1995        5.9   6.6
# 2005        4.9   5.5
# 2011        8.3  10.7
# 2015        5.7   6.1

# %%
url = "https://datascience.quantecon.org/assets/data/state_unemployment.csv"
unemp_raw = pd.read_csv(url, parse_dates=["Date"])

# %%
unemp_raw.head()
# Out:
#         Date       state  LaborForce  UnemploymentRate
# 0 2000-01-01     Alabama   2142945.0               4.7
# 1 2000-01-01      Alaska    319059.0               6.3
# 2 2000-01-01     Arizona   2499980.0               4.1
# 3 2000-01-01    Arkansas   1264619.0               4.4
# 4 2000-01-01  California  16680246.0               5.0

# %%
unemp_all = (
    unemp_raw
    .reset_index()
    .pivot_table(index="Date", columns="state", values="UnemploymentRate")
)
unemp_all.head()
# Out:
# state       Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# Date
# 2000-01-01      4.7     6.3      4.1       4.4         5.0       2.8
# 2000-02-01      4.7     6.3      4.1       4.3         5.0       2.8
# 2000-03-01      4.6     6.3      4.0       4.3         5.0       2.7
# 2000-04-01      4.6     6.3      4.0       4.3         5.1       2.7
# 2000-05-01      4.5     6.3      4.0       4.2         5.1       2.7
#
# state       Connecticut  Delaware  Florida  Georgia  ...  South Dakota  \
# Date                                                 ...
# 2000-01-01          2.8       3.5      3.7      3.7  ...           2.4
# 2000-02-01          2.7       3.6      3.7      3.6  ...           2.4
# 2000-03-01          2.6       3.6      3.7      3.6  ...           2.4
# 2000-04-01          2.5       3.7      3.7      3.7  ...           2.4
# 2000-05-01          2.4       3.7      3.7      3.7  ...           2.4
#
# ...

# %%
states = [
    "Arizona", "California", "Florida", "Illinois",
    "Michigan", "New York", "Texas"
]
unemp = unemp_all[states]
unemp.head()
# Out:
# state       Arizona  California  Florida  Illinois  Michigan  New York  Texas
# Date
# 2000-01-01      4.1         5.0      3.7       4.2       3.3       4.7    4.6
# 2000-02-01      4.1         5.0      3.7       4.2       3.2       4.7    4.6
# 2000-03-01      4.0         5.0      3.7       4.3       3.2       4.6    4.5
# 2000-04-01      4.0         5.1      3.7       4.3       3.3       4.6    4.4
# 2000-05-01      4.0         5.1      3.7       4.3       3.5       4.6    4.3

# %%
unemp.plot(figsize=(8, 6))
# Out:
# <Axes: xlabel='Date'>

# %%
unemp.mean()
# Out:
# state
# Arizona       6.301389
# California    7.299074
# Florida       6.048611
# Illinois      6.822685
# Michigan      7.492593
# New York      6.102315
# Texas         5.695370
# dtype: float64

# %%
def high_or_low(s):
    """
    Returns high if the mean of a Series object is above 6.5 and low if the mean is below 6.5
    """
    if s.mean() < 6.5:
        out = "Low"
    else: 
        out = "High"
    return out

# %%
unemp.agg(high_or_low)
# Out:
# state
# Arizona        Low
# California    High
# Florida        Low
# Illinois      High
# Michigan      High
# New York       Low
# Texas          Low
# dtype: object

# %%
unemp.pct_change(fill_method = None).head() # Skip calculation for missing data
# Out:
# state       Arizona  California  Florida  Illinois  Michigan  New York  \
# Date
# 2000-01-01      NaN         NaN      NaN       NaN       NaN       NaN
# 2000-02-01  0.00000        0.00      0.0   0.00000 -0.030303  0.000000
# 2000-03-01 -0.02439        0.00      0.0   0.02381  0.000000 -0.021277
# 2000-04-01  0.00000        0.02      0.0   0.00000  0.031250  0.000000
# 2000-05-01  0.00000        0.00      0.0   0.00000  0.060606  0.000000
#
# state          Texas
# Date
# 2000-01-01       NaN
# 2000-02-01  0.000000
# 2000-03-01 -0.021739
# 2000-04-01 -0.022222
# 2000-05-01 -0.022727

# %%
#At each date, what is the minimum unemployment rate across all states in our sample? 

unemp_all.min(axis= 1)
# Out:
# Date
# 2000-01-01    2.4
# 2000-02-01    2.4
# 2000-03-01    2.4
# 2000-04-01    2.4
# 2000-05-01    2.3
#              ...
# 2017-08-01    2.2
# 2017-09-01    2.2
# 2017-10-01    2.1
# 2017-11-01    2.1
# 2017-12-01    2.1
# Length: 216, dtype: float64

# %%
#What was the median unemployment rate in each state?

unemp_all.median()
# Out:
# state
# Alabama           5.90
# Alaska            7.00
# Arizona           5.80
# Arkansas          5.50
# California        6.50
# Colorado          5.20
# Connecticut       5.30
# Delaware          4.50
# Florida           5.35
# Georgia           5.30
# Hawaii            4.10
# Idaho             5.00
# Illinois          6.15
# Indiana           5.30
# Iowa              4.20
# Kansas            4.90
# Kentucky          5.70
# Louisiana         6.10
# Maine             4.80
# Maryland          4.40
# Massachusetts     5.10
# Michigan          7.00
# Minnesota         4.50
# Mississippi       6.60
# Missouri          5.50
# Montana           4.60
# Nebraska          3.60
# Nevada            5.65
# New Hampshire     3.80
# New Mexico        6.00
# New York          5.70
# New jersey        5.40
# North Carolina    5.90
# North Dakota      3.20
# Ohio              5.80
# Oklahoma          4.60
# Oregon            6.85
# Pennsylvania      5.45
# Rhode island      5.40
# ...

# %%
#What was the maximum unemployment rate across the states in our sample? What state did it happen in? In what month/year was this achieved?

print("The maximum unemployment rate was", unemp_all.loc["06/01/2009", "Michigan"])

print("It happened in", unemp_all.max().idxmax())

print("It was achieved in", unemp_all.max(axis=1).idxmax())
# Out:
# The maximum unemployment rate was 14.6
# It happened in Michigan
# It was achieved in 2009-06-01 00:00:00

# %%
#Classify each state as high or low volatility based on whether the variance of their unemployment is above or below 4.

def volatility_HL(unemp_all):
    if unemp_all.var() < 4:
        out = "Low"
    else:
        out = "High"
    return out
unemp_all.agg(volatility_HL)
# Out:
# state
# Alabama           High
# Alaska             Low
# Arizona           High
# Arkansas           Low
# California        High
# Colorado           Low
# Connecticut        Low
# Delaware           Low
# Florida           High
# Georgia           High
# Hawaii             Low
# Idaho              Low
# Illinois           Low
# Indiana           High
# Iowa               Low
# Kansas             Low
# Kentucky           Low
# Louisiana          Low
# Maine              Low
# Maryland           Low
# Massachusetts      Low
# Michigan          High
# Minnesota          Low
# Mississippi        Low
# Missouri           Low
# Montana            Low
# Nebraska           Low
# Nevada            High
# New Hampshire      Low
# New Mexico         Low
# New York           Low
# New jersey         Low
# North Carolina    High
# North Dakota       Low
# Ohio               Low
# Oklahoma           Low
# Oregon            High
# Pennsylvania       Low
# Rhode island      High
# ...
